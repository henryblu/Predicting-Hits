# %% [markdown]
# This notebook is used to fetch the playlist url from the playlist name. This dictionary will be used later on to return a list of playlist urls to the user.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

import random
import string
import pandas as pd
import numpy as np


#Write here the client ID and secret ID from spotify API
SPOTIPY_CLIENT_ID = ''
SPOTIPY_CLIENT_SECRET = ''
REDIRECT_URI = 'http://localhost:7000/callback'
scope = "user-library-read"

cache_handler = spotipy.cache_handler.MemoryCacheHandler()
auth_manager = SpotifyClientCredentials(client_id = SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET, cache_handler=cache_handler)
sp = spotipy.Spotify(auth_manager = auth_manager)


df = pd.read_csv('finnish_playlist_data.csv')

df = df.drop_duplicates(subset = ['id', 'playlist_name']).reset_index(drop = True)
df = df[['playlist_name', 'song_name', 'id', 'artist', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'mode', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']]
df = df.sort_values(by=['playlist_name']).reset_index(drop = True)
df
# Out:
#           playlist_name                           song_name  \
# 0       #vainsuomihitit                               PLAYA
# 1       #vainsuomihitit                         Ikävä meitä
# 2       #vainsuomihitit                     Voimaa ja valoa
# 3       #vainsuomihitit                    Vapaa (Mestarit)
# 4       #vainsuomihitit  Kohta sataa - Vain elämää kausi 13
# ...                 ...                                 ...
# 3384  Viikonloppufiilis                Youth (feat. Khalid)
# 3385  Viikonloppufiilis                             Trigger
# 3386  Viikonloppufiilis            What About Us - Acoustic
# 3387  Viikonloppufiilis           2 Hearts (feat. Gia Koka)
# 3388  Viikonloppufiilis                                 Bad
#
#                           id         artist  popularity  danceability  energy  \
# 0     1vQoEeHAKr8OIGIMFY2yAj    Jami Faltin          51         0.859   0.565
# 1     10G4sUXO33FT5SyRTdE4GM           Miri          39         0.559   0.729
# 2     3F2Sm1D7m7uz1i0Ytrh19c           Yona          41         0.552   0.403
# 3     6xUyD4l2ToLbUuazyY1aHV      Ellinoora          39         0.294   0.726
# 4     2FlcD6o29XKTcHCJpvTTiO       Jyrki 69          37         0.662   0.794
# ...                      ...            ...         ...           ...     ...
# 3384  1h0yImRPIVAjhhHeNVlTuC   Shawn Mendes          68         0.534   0.596
# 3385  0Z26mbSHJ1dkUu7g9DDgif    Major Lazer          60         0.570   0.585
# 3386  7e4Pftu2tzDeY0W0690OKQ  Thomas Daniel          61         0.427   0.229
# 3387  0EdgK7ASb4kfRkW8pVMN02      Sam Feldt          62         0.503   0.754
# 3388  3xRcQ04b0l5RiU2w7lJhCD      James Bay          61         0.549   0.413
#
#       key  loudness  speechiness  mode  acousticness  instrumentalness  \
# 0       8    -5.485       0.1560     1       0.35100          0.000005
# 1       2    -6.657       0.1150     0       0.52800          0.000854
# 2       7    -9.076       0.0850     1       0.56600          0.000021
# 3      10    -6.615       0.0472     0       0.00537          0.000049
# 4       4    -7.423       0.0326     0       0.00554          0.742000
# ...   ...       ...          ...   ...           ...               ...
# 3384    6    -6.653       0.1170     0       0.56000          0.000000
# 3385    8    -7.041       0.2510     1       0.12800          0.000105
# 3386    4   -11.564       0.0364     1       0.93500          0.000007
# 3387    7    -3.634       0.0424     1       0.26400          0.000058
# 3388    4    -5.587       0.0362     1       0.75600          0.000000
#
#       liveness  valence    tempo  duration_ms  time_signature
# 0       0.1090   0.9570  142.065       128258               4
# 1       0.1090   0.4650  191.782       165342               4
# 2       0.1020   0.4930  148.030       217854               4
# 3       0.1260   0.0387  104.926       365038               3
# 4       0.1680   0.6310  108.049       191200               4
# ...        ...      ...      ...          ...             ...
# 3384    0.1330   0.3240  100.121       190867               4
# 3385    0.1110   0.3780   97.285       171987               4
# 3386    0.0958   0.2220  125.195       255511               5
# 3387    0.2970   0.5970  116.524       186750               4
# 3388    0.0939   0.2900  139.981       225920               4
#
# [3389 rows x 18 columns]

# %% [markdown]
# The cell below finds all playlist names, and makes a dictionary where key value pairs are the {playlist name : playlist url}

# %%
playlist_names = df['playlist_name'].unique()

playlist_name_to_url = {}

for name in playlist_names:
    playlist_name_to_url[name]=sp.search(q = name, type = 'playlist', market = 'FI')['playlists']['items'][0]['external_urls']['spotify']

playlist_name_to_url
# Out:
# {'#vainsuomihitit': 'https://open.spotify.com/playlist/37i9dQZF1DWUvzPS8uIABd',
#  '100 Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DWTw1ORfckhDu',
#  'Aitoa suomiräppiä': 'https://open.spotify.com/playlist/37i9dQZF1DWTNh5Hm8ZKkQ',
#  'Best New Pop': 'https://open.spotify.com/playlist/37i9dQZF1DX3bf2kWnX8S4',
#  'Big Country': 'https://open.spotify.com/playlist/4tgNW6bpUv6QQFDJ4lJbEp',
#  'Bileräppiä': 'https://open.spotify.com/playlist/37i9dQZF1DWUeNVNpn1lPA',
#  'Calming Acoustic': 'https://open.spotify.com/playlist/37i9dQZF1DXaImRpG7HXqp',
#  'Chill Pop': 'https://open.spotify.com/playlist/37i9dQZF1DX0MLFaUdXnjA',
#  'Chill Vibes': 'https://open.spotify.com/playlist/37i9dQZF1DX889U0CL85jj',
#  'EQUAL Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DX4B8pEz8Paq4',
#  'Ensisoitossa': 'https://open.spotify.com/playlist/37i9dQZF1DXbsb4MvKbVAY',
#  'Evening Acoustic': 'https://open.spotify.com/playlist/37i9dQZF1DXcWBRiUaG3o5',
#  'Feel Good Beats': 'https://open.spotify.com/playlist/37i9dQZF1DXcNb6Ba0LuVc',
#  'Herkimmät suomalaiset biisit': 'https://open.spotify.com/playlist/37i9dQZF1DWW1FLvEAcimu',
#  'Hit Replay Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DX8sjRUtu4bjr',
#  'Hyvän olon treenilista': 'https://open.spotify.com/playlist/37i9dQZF1DWSEIMgzhSu5e',
#  'Internet People': 'https://open.spotify.com/playlist/37i9dQZF1DX6OgmB2fwLGd',
#  'Iskelmä kuuluu kaikille': 'https://open.spotify.com/playlist/37i9dQZF1DWVOar3rtQpLZ',
#  "It's Hits Suomi": 'https://open.spotify.com/playlist/37i9dQZF1DX64Cx4vTeaRB',
#  'Jonnet ei muista': 'https://open.spotify.com/playlist/37i9dQZF1DWXVBw4Z7cIDC',
#  'Jytää, purkkaa ja Finnhitsejä': 'https://open.spotify.com/playlist/37i9dQZF1DXdvA6jt8SAU9',
#  'Lava Lamp': 'https://open.spotify.com/playlist/37i9dQZF1DWWtqHeytOZ8f',
#  'Matkalaulut': 'https://open.spotify.com/playlist/37i9dQZF1DX3zHI0Yn6qtf',
#  'Metallia Suomesta': 'https://open.spotify.com/playlist/37i9dQZF1DX8oyW0kIcHwJ',
#  'New Music Friday Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DWXtcXUwhuzFM',
#  'Nousussa': 'https://open.spotify.com/playlist/37i9dQZF1DXdJFpsr4Sn91',
#  'POLLEN': 'https://open.spotify.com/playlist/37i9dQZF1DWWBHeXOYZf74',
#  'Paras fiilis!': 'https://open.spotify.com/playlist/37i9dQZF1DWSLxUsaAEkMD',
#  'Parhaat suomihitit 00-luvulta': 'https://open.spotify.com/playlist/37i9dQZF1DX5J8OeHucu2I',
#  'Poppia työpäivään': 'https://open.spotify.com/playlist/37i9dQZF1DX8JRb0iafpW2',
#  'Power Gaming': 'https://open.spotify.com/playlist/37i9dQZF1DX6taq20FeuKj',
#  'Rentoa konerytmiä': 'https://open.spotify.com/playlist/37i9dQZF1DX4JZt84Ykelm',
#  'Suomi-indie tänään': 'https://open.spotify.com/playlist/37i9dQZF1DWWHpR486dzm3',
#  'Suomirock tänään': 'https://open.spotify.com/playlist/37i9dQZF1DWSTzzP5k4u3n',
#  'Suomirockin klassikot': 'https://open.spotify.com/playlist/37i9dQZF1DWTREX34Zufzd',
#  'Tästä tulee hyvä päivä': 'https://open.spotify.com/playlist/37i9dQZF1DX6J3FucTDfai',
#  'Uuden suomalaisen musiikin lista': 'https://open.spotify.com/playlist/37i9dQZF1DX8txPsVVyl0W',
#  'Viikonloppufiilis': 'https://open.spotify.com/playlist/37i9dQZF1DX43FUw8I0F7b'}

# %% [markdown]
# Time to save the dictionary for later use

# %%
import joblib

joblib.dump(value = playlist_name_to_url, filename = './objects/playlist_name_to_url')
# Out:
# ['./objects/playlist_name_to_url']

# %% [markdown]
# Testing whether it works

# %%
joblib.load(filename = './objects/playlist_name_to_url')
# Out:
# {'#vainsuomihitit': 'https://open.spotify.com/playlist/37i9dQZF1DWUvzPS8uIABd',
#  '100 Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DWTw1ORfckhDu',
#  'Aitoa suomiräppiä': 'https://open.spotify.com/playlist/37i9dQZF1DWTNh5Hm8ZKkQ',
#  'Best New Pop': 'https://open.spotify.com/playlist/37i9dQZF1DX3bf2kWnX8S4',
#  'Big Country': 'https://open.spotify.com/playlist/4tgNW6bpUv6QQFDJ4lJbEp',
#  'Bileräppiä': 'https://open.spotify.com/playlist/37i9dQZF1DWUeNVNpn1lPA',
#  'Calming Acoustic': 'https://open.spotify.com/playlist/37i9dQZF1DXaImRpG7HXqp',
#  'Chill Pop': 'https://open.spotify.com/playlist/37i9dQZF1DX0MLFaUdXnjA',
#  'Chill Vibes': 'https://open.spotify.com/playlist/37i9dQZF1DX889U0CL85jj',
#  'EQUAL Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DX4B8pEz8Paq4',
#  'Ensisoitossa': 'https://open.spotify.com/playlist/37i9dQZF1DXbsb4MvKbVAY',
#  'Evening Acoustic': 'https://open.spotify.com/playlist/37i9dQZF1DXcWBRiUaG3o5',
#  'Feel Good Beats': 'https://open.spotify.com/playlist/37i9dQZF1DXcNb6Ba0LuVc',
#  'Herkimmät suomalaiset biisit': 'https://open.spotify.com/playlist/37i9dQZF1DWW1FLvEAcimu',
#  'Hit Replay Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DX8sjRUtu4bjr',
#  'Hyvän olon treenilista': 'https://open.spotify.com/playlist/37i9dQZF1DWSEIMgzhSu5e',
#  'Internet People': 'https://open.spotify.com/playlist/37i9dQZF1DX6OgmB2fwLGd',
#  'Iskelmä kuuluu kaikille': 'https://open.spotify.com/playlist/37i9dQZF1DWVOar3rtQpLZ',
#  "It's Hits Suomi": 'https://open.spotify.com/playlist/37i9dQZF1DX64Cx4vTeaRB',
#  'Jonnet ei muista': 'https://open.spotify.com/playlist/37i9dQZF1DWXVBw4Z7cIDC',
#  'Jytää, purkkaa ja Finnhitsejä': 'https://open.spotify.com/playlist/37i9dQZF1DXdvA6jt8SAU9',
#  'Lava Lamp': 'https://open.spotify.com/playlist/37i9dQZF1DWWtqHeytOZ8f',
#  'Matkalaulut': 'https://open.spotify.com/playlist/37i9dQZF1DX3zHI0Yn6qtf',
#  'Metallia Suomesta': 'https://open.spotify.com/playlist/37i9dQZF1DX8oyW0kIcHwJ',
#  'New Music Friday Suomi': 'https://open.spotify.com/playlist/37i9dQZF1DWXtcXUwhuzFM',
#  'Nousussa': 'https://open.spotify.com/playlist/37i9dQZF1DXdJFpsr4Sn91',
#  'POLLEN': 'https://open.spotify.com/playlist/37i9dQZF1DWWBHeXOYZf74',
#  'Paras fiilis!': 'https://open.spotify.com/playlist/37i9dQZF1DWSLxUsaAEkMD',
#  'Parhaat suomihitit 00-luvulta': 'https://open.spotify.com/playlist/37i9dQZF1DX5J8OeHucu2I',
#  'Poppia työpäivään': 'https://open.spotify.com/playlist/37i9dQZF1DX8JRb0iafpW2',
#  'Power Gaming': 'https://open.spotify.com/playlist/37i9dQZF1DX6taq20FeuKj',
#  'Rentoa konerytmiä': 'https://open.spotify.com/playlist/37i9dQZF1DX4JZt84Ykelm',
#  'Suomi-indie tänään': 'https://open.spotify.com/playlist/37i9dQZF1DWWHpR486dzm3',
#  'Suomirock tänään': 'https://open.spotify.com/playlist/37i9dQZF1DWSTzzP5k4u3n',
#  'Suomirockin klassikot': 'https://open.spotify.com/playlist/37i9dQZF1DWTREX34Zufzd',
#  'Tästä tulee hyvä päivä': 'https://open.spotify.com/playlist/37i9dQZF1DX6J3FucTDfai',
#  'Uuden suomalaisen musiikin lista': 'https://open.spotify.com/playlist/37i9dQZF1DX8txPsVVyl0W',
#  'Viikonloppufiilis': 'https://open.spotify.com/playlist/37i9dQZF1DX43FUw8I0F7b'}
